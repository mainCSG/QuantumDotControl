# %% [markdown]
# ## Need .venv with Python either 3.8 or 3.9

# %%
# !python -m pip install -U pip

# %%
# !python -m pip install --no-cache-dir quantify-core
# !python -m pip install --no-cache-dir quantify-scheduler

# %% [markdown]
# ## Resources
# https://quantify-os.org/docs/quantify-core/v0.7.4/index.html
# https://quantify-os.org/docs/quantify-scheduler/v0.18.1/user/index.html
# https://qblox-qblox-instruments.readthedocs-hosted.com/en/main/cluster/index.html

# %%
# !python -m pip list | grep quantify
# Out:
# quantify-core             0.7.4
# quantify-scheduler        0.18.1

# %%
import quantify_scheduler

# %%
from quantify_scheduler.device_under_test.quantum_device import QuantumDevice
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 from quantify_scheduler.device_under_test.quantum_device import QuantumDevice
# ----> 2 test = QuantumDevice()
#
# File ~/Documents/uwaterloo/research/QuantumDotControl/.venv/lib/python3.9/site-packages/qcodes/instrument/instrument_meta.py:36, in InstrumentMeta.__call__(cls, *args, **kwargs)
#      31 def __call__(cls, *args: Any, **kwargs: Any) -> Any:
#      32     """
#      33     Overloads `type.__call__` to add code that runs only if __init__ completes
#      34     successfully.
#      35     """
# ---> 36     new_inst = super().__call__(*args, **kwargs)
#      37     is_abstract = new_inst._is_abstract()
#      38     if is_abstract:
#
# TypeError: __init__() missing 1 required positional argument: 'name'
