# %%
from qcodes.station import Station
import inspect
import os

test_station = Station()
print(test_station.snapshot())
print(test_station.components)

os.chdir('..')
test_station.load_config(os.path.join(os.getcwd(),'configs\\dummy_station.yaml'))
# Out:
# {'instruments': {}, 'parameters': {}, 'components': {}, 'config': None}
# {}
# c:\Users\kite\miniconda3\envs\autotuning\Lib\site-packages\qcodes\station.py:507: ValidationWarning: 'c:\\Users\\kite\\Dev\\Python\\QuantumDotControl\\configs\\dummy_station.yaml' is not of type 'object'
#
# Failed validating 'type' in schema:
#     {'type': 'object',
#      'title': 'QCoDeS Station configuration validation',
#      'description': 'This schema serves the purpose of validating yaml '
#                     'files that describe a QCoDeS station. See more here: '
#                     'https://qcodes.github.io/Qcodes/examples/Station.html#Configuring-the-Station-by-using-a-YAML-configuration-file',
#      '$schema': 'http://json-schema.org/draft-07/schema#',
#      'definitions': {'instruments': {'enum': ['']},
#                      'parameter_base': {'$comment': 'A common base for the '
#                                                     'properties shared by '
# ...
